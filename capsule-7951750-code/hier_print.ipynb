# %%
from hier_tree import *

# %% [markdown]
# # Load hierarchy

# %%
# Location of hierarchy (.pkl)
save_dir = "/root/capsule/data/aes"
# Hierarchy name = file_name_version
file_name = "aes_golden_hier"

top_module_aes = load_tree(save_dir, file_name)
# Out:
# Tree loaded from: /root/capsule/data/aes/aes_golden_hier.pkl

# %% [markdown]
# # Traverse modules in hierarchy

# %%
traverse_tree(top_module_aes)
# Out:
#  [aes_128]
#   - module_name: aes_128
#   - module_header: module aes_128 (input wire clk, input wire reset, input wire enable, input wire mode, input wire [127:0] key, input wire [127:0] data_in, output reg [127:0] data_out, output reg done);
# ...

# %% [markdown]
# # Visualize hierarchy

# %%
visualize_output_tree(top_module_aes)
