# %% [markdown]
# # [2nd stage] Verilog Code Generation

# %% [markdown]
# ### No testbench generation, functional refinement with verified testbench

# %%
from prompts import *
from hier_tree import *
from code_gen import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from prompts import *
#       2 from hier_tree import *
# ----> 3 from code_gen import *
#
# File ~/capsule/code/code_gen.py:40
#      38 from hier_tree import *
#      39 from prompts import *
# ---> 40 from API_key import client
#      41 from textwrap import dedent
#      44 def find_node_by_name(root, target_name):
#
# File ~/capsule/code/API_key.py:1
# ----> 1 from openai import OpenAI
#       3 client = OpenAI (
#       4     api_key= "your_key",
#       5     organization= "your_organization",
#       6     project= "your_project"
#       7 )
#
# ModuleNotFoundError: No module named 'openai'

# %%
save_dir = "/home/gnchang/000_LLM/LAD25/5_experiment/exp1/proposed/aes128"
file_name = "aes_128_ver6"
version= ""

top_module_aes = load_tree(save_dir, file_name, version)

# %%
output_dir = "/home/gnchang/000_LLM/LAD25/5_experiment/exp3/aes128/12"
tb_path = "/home/gnchang/000_LLM/LAD25/5_experiment/exp3/aes128/8/testbench"
second_Loop_verified_tb(top_module_aes, output_dir, tb_path)
